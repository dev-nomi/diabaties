# %%
import pandas as pd

# %%
iot_sample_data = pd.read_csv("iot_system_data_unannotated.csv")
iot_sample_data.head()
# Out:
#     Temp1      HR       Spo2        BP        GL
# 0  Normal  Normal   Critical  Elevated    Normal
# 1     Low  Normal  Worrisome  Elevated       Low
# 2     Low     Low  Worrisome    Normal  Elevated
# 3     Low  Normal  Worrisome    Normal       Low
# 4     Low     Low     Normal    Normal  Elevated

# %%
standard_sample_data = pd.read_csv("standard_system_data_unannotated.csv")
standard_sample_data.head()
# Out:
#     Temp1      HR       Spo2        BP        GL
# 0  Normal  Normal   Critical  Elevated  Elevated
# 1     Low  Normal  Worrisome  Elevated      High
# 2     Low  Normal  Worrisome    Normal  Elevated
# 3     Low  Normal  Worrisome    Normal      High
# 4     Low     Low     Normal    Normal  Elevated

# %%
def is_healthy(Temp1,HR,Spo2,BP,GL):
    return (
        Temp1 == 'Normal' and HR == 'Normal' and Spo2 == 'Normal' and BP == 'Normal' and GL == 'Normal'
    )

# %%
def is_moderate(Temp1,HR,Spo2,BP,GL):
    return (
        (Temp1 == 'Low' or Temp1 == 'High') or 
        (HR == 'Low' or HR == 'High') or 
        (BP == 'Low' or BP == 'High')
    )

# %%
def is_unhealthy(Temp1,HR,Spo2,BP,GL):
    return (
        ((Temp1 == 'Low' or Temp1 == 'High') and (HR == 'Low' or HR == 'High')) or 
        ((BP == 'Low' or BP == 'High') and (HR == 'Low' or HR == 'High')) or
        ((BP == 'Low' or BP == 'High') and (Temp1 == 'Low' or Temp1 == 'High'))
    )

# %%
def is_very_unhealthy(Temp1,HR,Spo2,BP,GL):
    return (
        (Temp1 == 'Low' or Temp1 == 'High') and 
        (HR == 'Low' or HR == 'High') and
        (BP == 'Low' or BP == 'High')
    )

# %%
def is_critical(Temp1,HR,Spo2,BP,GL):
    return (
        (GL == 'Low' or GL == 'High') or
        (Spo2 == 'Critical')
    )

# %%
def is_very_critical(Temp1,HR,Spo2,BP,GL):
    return (
        ((GL == 'Low' or GL == 'High') and (Spo2 == 'Critical') and (Temp1 == 'Low' or Temp1 == 'High')) or
        ((GL == 'Low' or GL == 'High') and (Spo2 == 'Critical') and (HR == 'Low' or HR == 'High')) or
        ((GL == 'Low' or GL == 'High') and (Spo2 == 'Critical') and (BP == 'Low' or BP == 'High')) or
        ((GL == 'Low' or GL == 'High') and (HR == 'Low' or HR == 'High') and (BP == 'Low' or BP == 'High')) or
        ((GL == 'Low' or GL == 'High') and (Temp1 == 'Low' or Temp1 == 'High') and (BP == 'Low' or BP == 'High')) or
        ((GL == 'Low' or GL == 'High') and (Temp1 == 'Low' or Temp1 == 'High') and (HR == 'Low' or HR == 'High')) or
        ((GL == 'Low' or GL == 'High') and (Spo2 == 'Critical'))
    )

# %%
outcome = []
for index, row in iot_sample_data.iterrows():
    if is_healthy(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Healthy")
    elif is_very_critical(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Very Critical")
    elif is_critical(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Critical")
    elif is_very_unhealthy(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Very Unhealthy")
    elif is_unhealthy(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Unhealthy")
    elif is_moderate(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Moderate")
    else:
        outcome.append("None")

# %%
iot_sample_data["Condition"] = outcome  
pd.set_option("display.max_rows", None, "display.max_columns", None)
iot_sample_data
# Out:
#      Temp1      HR       Spo2        BP        GL       Condition
# 0   Normal  Normal   Critical  Elevated    Normal        Critical
# 1      Low  Normal  Worrisome  Elevated       Low        Critical
# 2      Low     Low  Worrisome    Normal  Elevated       Unhealthy
# 3      Low  Normal  Worrisome    Normal       Low        Critical
# 4      Low     Low     Normal    Normal  Elevated       Unhealthy
# 5   Normal     Low     Normal  Elevated      High        Critical
# 6   Normal     Low     Normal  Elevated       Low        Critical
# 7   Normal     Low     Normal  Elevated       Low        Critical
# 8     High     Low     Normal  Elevated    Normal       Unhealthy
# 9   Normal     Low     Normal    Normal      High        Critical
# 10  Normal     Low     Normal       Low    Normal       Unhealthy
# 11  Normal     Low     Normal       Low      High   Very Critical
# 12  Normal     Low     Normal       Low       Low   Very Critical
# 13  Normal  Normal   Critical  Elevated       Low   Very Critical
# 14  Normal     Low   Critical       Low      High   Very Critical
# 15     Low  Normal   Critical    Normal    Normal        Critical
# 16     Low     Low   Critical    Normal      High   Very Critical
# 17     Low     Low   Critical    Normal       Low   Very Critical
# 18     Low     Low     Normal    Normal       Low   Very Critical
# 19     Low     Low   Critical    Normal       Low   Very Critical
# 20     Low     Low     Normal    Normal      High   Very Critical
# 21     Low     Low     Normal       Low      High   Very Critical
# 22     Low     Low     Normal       Low       Low   Very Critical
# 23     Low     Low     Normal       Low       Low   Very Critical
# 24     Low     Low     Normal       Low       Low   Very Critical
# 25     Low     Low     Normal       Low       Low   Very Critical
# 26     Low     Low     Normal       Low       Low   Very Critical
# 27     Low     Low     Normal       Low      High   Very Critical
# 28     Low     Low     Normal       Low    Normal  Very Unhealthy
# 29     Low     Low     Normal       Low      High   Very Critical
# 30  Normal     Low     Normal       Low      High   Very Critical
# 31     Low     Low     Normal    Normal    Normal       Unhealthy
# 32     Low     Low  Worrisome       Low    Normal  Very Unhealthy
# 33     Low     Low     Normal       Low       Low   Very Critical
# 34     Low     Low     Normal       Low       Low   Very Critical
# 35     Low     Low     Normal    Normal      High   Very Critical
# 36  Normal     Low     Normal    Normal       Low        Critical
# 37     Low     Low   Critical       Low      High   Very Critical
# 38  Normal     Low   Critical       Low       Low   Very Critical
# 39    High     Low   Critical       Low       Low   Very Critical
# 40    High     Low   Critical       Low      High   Very Critical
# 41    High     Low   Critical       Low    Normal        Critical
# 42    High     Low   Critical       Low  Elevated        Critical
# 43    High     Low   Critical       Low       Low   Very Critical
# 44    High  Normal   Critical    Normal       Low   Very Critical
# 45    High  Normal  Worrisome    Normal    Normal        Moderate
# 46     Low  Normal  Worrisome       Low       Low   Very Critical
# 47     Low     Low   Critical       Low      High   Very Critical
# 48     Low     Low  Worrisome       Low      High   Very Critical
# 49  Normal     Low     Normal       Low    Normal       Unhealthy
# 50    High     Low     Normal    Normal       Low   Very Critical
# 51  Normal     Low     Normal    Normal       Low        Critical
# 52     Low     Low   Critical    Normal      High   Very Critical
# 53     Low     Low     Normal       Low       Low   Very Critical
# 54  Normal     Low   Critical       Low      High   Very Critical
# 55  Normal  Normal   Critical    Normal       Low   Very Critical
# 56    High     Low   Critical    Normal    Normal        Critical
# 57    High  Normal   Critical    Normal      High   Very Critical
# 58    High  Normal   Critical       Low       Low   Very Critical
# 59    High  Normal     Normal    Normal       Low        Critical
# 60  Normal     Low   Critical       Low    Normal        Critical
# 61     Low  Normal   Critical       Low    Normal        Critical
# 62    High     Low   Critical       Low      High   Very Critical
# 63  Normal    High     Normal       Low    Normal       Unhealthy
# 64  Normal    High  Worrisome       Low      High   Very Critical
# 65    High    High   Critical      High  Elevated        Critical
# 66    High     Low   Critical       Low    Normal        Critical
# 67    High     Low   Critical       Low       Low   Very Critical
# 68    High     Low   Critical       Low       Low   Very Critical
# 69     Low     Low   Critical       Low    Normal        Critical
# 70     Low     Low   Critical       Low       Low   Very Critical
# 71     Low  Normal   Critical    Normal    Normal        Critical
# 72     Low     Low   Critical       Low    Normal        Critical
# 73  Normal  Normal     Normal       Low      High        Critical
# 74  Normal  Normal     Normal       Low      High        Critical
# 75  Normal     Low     Normal  Elevated       Low        Critical
# 76  Normal     Low  Worrisome       Low       Low   Very Critical
# 77     Low     Low   Critical    Normal       Low   Very Critical
# 78  Normal  Normal   Critical    Normal    Normal        Critical
# 79     Low  Normal  Worrisome    Normal      High        Critical
# 80     Low  Normal     Normal    Normal    Normal        Moderate
# 81     Low  Normal     Normal    Normal    Normal        Moderate
# 82     Low  Normal     Normal    Normal      High        Critical
# 83    High  Normal     Normal  Elevated       Low        Critical
# 84     Low  Normal   Critical    Normal       Low   Very Critical
# 85     Low     Low   Critical    Normal    Normal        Critical
# 86     Low     Low     Normal       Low    Normal  Very Unhealthy
# 87     Low     Low   Critical       Low      High   Very Critical
# 88     Low     Low   Critical       Low       Low   Very Critical
# 89     Low     Low   Critical       Low    Normal        Critical
# 90     Low     Low   Critical       Low      High   Very Critical
# 91     Low     Low  Worrisome    Normal    Normal       Unhealthy
# 92     Low     Low     Normal    Normal      High   Very Critical
# 93     Low     Low     Normal    Normal       Low   Very Critical
# 94     Low  Normal   Critical    Normal       Low   Very Critical
# 95     Low  Normal   Critical    Normal       Low   Very Critical
# 96     Low  Normal     Normal    Normal    Normal        Moderate
# 97    High     Low  Worrisome    Normal      High   Very Critical
# 98    High  Normal   Critical    Normal    Normal        Critical
# 99    High  Normal   Critical    Normal       Low   Very Critical

# %%
# saving the dataframe
iot_sample_data.to_csv('iot_sample_data_annotated.csv',index = False, header = True)

# %%
outcome = []
for index, row in standard_sample_data.iterrows():
    if is_healthy(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Healthy")
    elif is_very_critical(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Very Critical")
    elif is_critical(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Critical")
    elif is_very_unhealthy(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Very Unhealthy")
    elif is_unhealthy(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Unhealthy")
    elif is_moderate(row['Temp1'],row['HR'],row['Spo2'],row['BP'],row['GL']):
        outcome.append("Moderate")
    else:
        outcome.append("None")

# %%
standard_sample_data["Condition"] = outcome  
pd.set_option("display.max_rows", None, "display.max_columns", None)
standard_sample_data
# Out:
#      Temp1      HR       Spo2        BP        GL       Condition
# 0   Normal  Normal   Critical  Elevated  Elevated        Critical
# 1      Low  Normal  Worrisome  Elevated      High        Critical
# 2      Low  Normal  Worrisome    Normal  Elevated        Moderate
# 3      Low  Normal  Worrisome    Normal      High        Critical
# 4      Low     Low     Normal    Normal  Elevated       Unhealthy
# 5   Normal     Low     Normal  Elevated      High        Critical
# 6   Normal     Low     Normal  Elevated  Elevated        Moderate
# 7   Normal     Low     Normal  Elevated      High        Critical
# 8     High     Low     Normal  Elevated    Normal       Unhealthy
# 9   Normal     Low     Normal    Normal      High        Critical
# 10  Normal     Low     Normal       Low    Normal       Unhealthy
# 11  Normal     Low     Normal       Low      High   Very Critical
# 12  Normal     Low     Normal       Low       Low   Very Critical
# 13  Normal  Normal   Critical  Elevated       Low   Very Critical
# 14  Normal     Low   Critical       Low      High   Very Critical
# 15     Low  Normal   Critical    Normal    Normal        Critical
# 16     Low     Low   Critical    Normal      High   Very Critical
# 17     Low     Low   Critical    Normal       Low   Very Critical
# 18     Low     Low     Normal    Normal       Low   Very Critical
# 19     Low     Low   Critical    Normal       Low   Very Critical
# 20     Low     Low     Normal    Normal      High   Very Critical
# 21     Low     Low     Normal       Low      High   Very Critical
# 22     Low     Low     Normal       Low       Low   Very Critical
# 23     Low     Low     Normal       Low       Low   Very Critical
# 24     Low     Low     Normal       Low       Low   Very Critical
# 25     Low     Low     Normal       Low       Low   Very Critical
# 26     Low     Low     Normal       Low       Low   Very Critical
# 27     Low     Low  Worrisome       Low      High   Very Critical
# 28     Low     Low     Normal       Low    Normal  Very Unhealthy
# 29     Low     Low     Normal       Low      High   Very Critical
# 30  Normal     Low     Normal       Low      High   Very Critical
# 31     Low     Low     Normal    Normal    Normal       Unhealthy
# 32     Low     Low  Worrisome       Low    Normal  Very Unhealthy
# 33     Low     Low     Normal       Low       Low   Very Critical
# 34     Low     Low     Normal       Low       Low   Very Critical
# 35     Low     Low     Normal    Normal      High   Very Critical
# 36  Normal     Low     Normal    Normal       Low        Critical
# 37     Low     Low   Critical       Low      High   Very Critical
# 38  Normal     Low   Critical       Low       Low   Very Critical
# 39    High     Low   Critical       Low       Low   Very Critical
# 40    High     Low   Critical       Low      High   Very Critical
# 41    High     Low   Critical       Low    Normal        Critical
# 42    High     Low   Critical       Low  Elevated        Critical
# 43    High     Low   Critical       Low       Low   Very Critical
# 44    High  Normal   Critical    Normal       Low   Very Critical
# 45    High  Normal  Worrisome    Normal    Normal        Moderate
# 46     Low  Normal  Worrisome       Low       Low   Very Critical
# 47     Low     Low   Critical       Low      High   Very Critical
# 48     Low     Low  Worrisome       Low      High   Very Critical
# 49  Normal     Low     Normal       Low    Normal       Unhealthy
# 50    High     Low     Normal    Normal  Elevated       Unhealthy
# 51  Normal     Low     Normal    Normal    Normal        Moderate
# 52     Low     Low   Critical    Normal      High   Very Critical
# 53     Low     Low     Normal       Low       Low   Very Critical
# 54  Normal     Low   Critical       Low      High   Very Critical
# 55  Normal  Normal   Critical    Normal    Normal        Critical
# 56    High     Low   Critical    Normal    Normal        Critical
# 57    High  Normal   Critical    Normal      High   Very Critical
# 58    High  Normal   Critical       Low       Low   Very Critical
# 59    High  Normal     Normal    Normal       Low        Critical
# 60  Normal     Low   Critical       Low    Normal        Critical
# 61     Low  Normal   Critical       Low    Normal        Critical
# 62    High     Low   Critical       Low      High   Very Critical
# 63  Normal    High     Normal       Low    Normal       Unhealthy
# 64  Normal    High  Worrisome       Low      High   Very Critical
# 65    High    High   Critical      High  Elevated        Critical
# 66    High     Low   Critical       Low    Normal        Critical
# 67    High     Low   Critical       Low       Low   Very Critical
# 68    High     Low   Critical       Low       Low   Very Critical
# 69     Low     Low   Critical       Low    Normal        Critical
# 70     Low     Low   Critical       Low       Low   Very Critical
# 71     Low  Normal   Critical    Normal    Normal        Critical
# 72     Low     Low   Critical       Low    Normal        Critical
# 73  Normal  Normal     Normal       Low      High        Critical
# 74  Normal  Normal     Normal       Low      High        Critical
# 75  Normal     Low     Normal  Elevated       Low        Critical
# 76  Normal     Low  Worrisome       Low       Low   Very Critical
# 77     Low     Low   Critical    Normal       Low   Very Critical
# 78  Normal  Normal   Critical    Normal    Normal        Critical
# 79     Low  Normal  Worrisome    Normal      High        Critical
# 80     Low    High     Normal    Normal    Normal       Unhealthy
# 81     Low  Normal     Normal    Normal    Normal        Moderate
# 82     Low  Normal     Normal    Normal      High        Critical
# 83    High  Normal     Normal  Elevated       Low        Critical
# 84     Low  Normal   Critical    Normal       Low   Very Critical
# 85     Low     Low   Critical    Normal    Normal        Critical
# 86     Low     Low     Normal       Low    Normal  Very Unhealthy
# 87     Low     Low   Critical       Low      High   Very Critical
# 88     Low     Low   Critical       Low       Low   Very Critical
# 89     Low     Low   Critical       Low    Normal        Critical
# 90     Low     Low   Critical       Low      High   Very Critical
# 91     Low     Low  Worrisome    Normal  Elevated       Unhealthy
# 92     Low     Low     Normal    Normal       Low   Very Critical
# 93     Low     Low     Normal    Normal       Low   Very Critical
# 94     Low  Normal   Critical    Normal       Low   Very Critical
# 95     Low  Normal   Critical    Normal       Low   Very Critical
# 96     Low  Normal     Normal    Normal    Normal        Moderate
# 97    High     Low  Worrisome    Normal      High   Very Critical
# 98    High  Normal   Critical    Normal    Normal        Critical
# 99    High  Normal   Critical    Normal       Low   Very Critical

# %%
# saving the dataframe
standard_sample_data.to_csv('standard_sample_data_annotated.csv',index = False, header = True)
